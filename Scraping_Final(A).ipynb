# %% [markdown]
# <a href="https://colab.research.google.com/github/Ashwin-113/Scrapping/blob/main/Scraping_Final(A).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 # Install required libraries
# !pip install beautifulsoup4 requests pandas

# Import necessary libraries
import requests  # Library for sending HTTP requests
from bs4 import BeautifulSoup  # Library for parsing HTML documents
import pandas as pd  # Library for data manipulation and analysis

# %%
# URL for Craigslist NYC Apartments for Rent
base_url = "https://newyork.craigslist.org/d/apartments-housing-for-rent/search/apa"

# %%
# Send a GET request to the website and store the response
response = requests.get(base_url)
response  # This will show the response object to check if the request was successful
# Out:
# <Response [200]>

# %%
# Parse the HTML content of the page with BeautifulSoup
soup = BeautifulSoup(response.text, 'html.parser')
soup  # This shows the parsed HTML content
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width,initial-scale=1" name="viewport"/>
# <meta content="craigslist" property="og:site_name"/>
# <meta content="preview" name="twitter:card"/>
# <meta content="new york apartments / housing for rent - craigslist" property="og:title"/>
# <meta content="new york apartments / housing for rent - craigslist" name="description"/>
# <meta content="new york apartments / housing for rent - craigslist" property="og:description"/>
# <meta content="https://newyork.craigslist.org/search/apa" property="og:url"/>
# <title>new york apartments / housing for rent - craigslist</title>
# <link href="https://newyork.craigslist.org/search/apa" rel="canonical"/>
# <link href="https://newyork.craigslist.org/search/apa" hreflang="x-default" rel="alternate"/>
# <link href="/favicon.ico" id="favicon" rel="icon">
# ...

# %%
# Find all 'div' elements on the page
div = soup.find_all("div")
div  # Displays all the 'div' elements found
# Out:
# [<div class="cl-content">
#  <main>
#  </main>
#  </div>,
#  <div id="curtain">
#  <div class="cover"></div>
#  <div class="content">
#  <div class="icom-"></div>
#  <div class="text loading">loading</div>
#  <div class="text reading">reading</div>
#  <div class="text writing">writing</div>
#  <div class="text saving">saving</div>
#  <div class="text searching">searching</div>
#  <div class="text message" id="curtainText"></div>
#  <div class="text unrecoverable">
#  <p><a href="#" id="cl-unrecoverable-hard-refresh" onclick="location.reload(true);">refresh the page.</a></p>
#  </div>
#  </div>
#  </div>,
#  <div class="cover"></div>,
#  <div class="content">
#  <div class="icom-"></div>
#  <div class="text loading">loading</div>
#  <div class="text reading">reading</div>
#  <div class="text writing">writing</div>
#  <div class="text saving">saving</div>
#  <div class="text searching">searching</div>
#  <div class="text message" id="curtainText"></div>
# ...

# %%
# Check the total number of 'div' elements
len(div)
# Out:
# 1418

# %%
# Find all 'div' elements with class "title" (assuming this is the correct class for titles)
mydivs = soup.find_all("div", {"class": "title"})
mydivs  # Displays all 'div' elements with class "title"
# Out:
# [<div class="title">DEAD CENTER CARROLL GARDENS! ABSOLUTE DREAM HOME WITH PRIVATE YARD!</div>,
#  <div class="title">Newly Renovated 3BR,, Heat &amp; Hot Water Included,, Walk to Subway!</div>,
#  <div class="title">Stunning 6th floor 2bed2bath+balcony+elevator+w/d in unit+gym+more</div>,
#  <div class="title">11/1 RENT STABILIZED FAB CHIC PRIME BUSHWICK 10 MIN NYC LAUNDRY ROOF</div>,
#  <div class="title">AMAZING 4 Bed 2 Bath + In-Unit W/D ✨20 min to CITY 🚊⚡️NO FEE</div>,
#  <div class="title">No fee ✓Modern &amp; spacious ✓Short commute ✓nightlife – TEXT</div>,
#  <div class="title">Artist’s Dream Loft in Bed-Stuy – Perfect for Creative Souls!</div>,
#  <div class="title">1Bd/1Ba w/Alcove Perfect for WFH off the G &amp;Herbert Von King Park!</div>,
#  <div class="title">**No Broker Fee** 4BR Available Now! 34-15 9th Street</div>,
#  <div class="title">✨SHOWING TONIGHT!!✨PROSPECT HEIGHTS- 1 BLOCK FROM PROSPECT PL STOP! !✨</div>,
# ...

# %%
# Find all 'div' elements with class "price" (assuming this is the correct class for prices)
pricedivs = soup.find_all("div", {"class": "price"})
pricedivs  # Displays all 'div' elements with class "price"
# Out:
# [<div class="price">$5,042</div>,
#  <div class="price">$3,300</div>,
#  <div class="price">$4,550</div>,
#  <div class="price">$2,622</div>,
#  <div class="price">$3,600</div>,
#  <div class="price">$3,000</div>,
#  <div class="price">$3,850</div>,
#  <div class="price">$2,950</div>,
#  <div class="price">$3,350</div>,
#  <div class="price">$2,599</div>,
#  <div class="price">$3,595</div>,
#  <div class="price">$3,050</div>,
#  <div class="price">$2,600</div>,
#  <div class="price">$3,800</div>,
#  <div class="price">$3,650</div>,
#  <div class="price">$3,200</div>,
#  <div class="price">$2,557</div>,
#  <div class="price">$7,150</div>,
#  <div class="price">$3,300</div>,
#  <div class="price">$4,700</div>,
#  <div class="price">$3,000</div>,
#  <div class="price">$4,200</div>,
#  <div class="price">$2,327</div>,
#  <div class="price">$2,700</div>,
#  <div class="price">$3,000</div>,
#  <div class="price">$2,750</div>,
#  <div class="price">$2,800</div>,
# ...

# %%
# Find all 'div' elements with class "location" (assuming this is the correct class for locations)
locdivs = soup.find_all("div", {"class": "location"})
locdivs  # Displays all 'div' elements with class "location"
# Out:
# [<div class="location">
#                          Carroll Gardens
#                      </div>,
#  <div class="location">
#                          Astoria
#                      </div>,
#  <div class="location">
#                          Bed Stuy @ Nostrand A/C + Bedford/Nostrand G
#                      </div>,
#  <div class="location">
#                          Bushwick
#                      </div>,
#  <div class="location">
#                          Bedstuy
#                      </div>,
#  <div class="location">
#                          Bushwick
#                      </div>,
#  <div class="location">
#                          Bedstuy
#                      </div>,
#  <div class="location">
#                          Bed-Stuy, Brooklyn
#                      </div>,
#  <div class="location">
#                          Long Island City
#                      </div>,
#  <div class="location">
#                          Prospect Heights
#                      </div>,
# ...

# %%
# Check the legth for each
print(len(mydivs))
print(len(pricedivs))
print(len(locdivs))
# Out:
# 351
# 351
# 351

# %%
# Initialize an empty list to store extracted data
data = []

# Loop through the elements based on the number of titles found (assuming all lists are the same length)
for i in range(len(mydivs)):
    # Extract text from each div and remove any extra whitespace
    title = mydivs[i].text.strip() if mydivs[i] else 'N/A'  # Get the title text or 'N/A' if not available
    price = pricedivs[i].text.strip() if pricedivs[i] else 'N/A'  # Get the price text or 'N/A' if not available
    location = locdivs[i].text.strip() if locdivs[i] else 'N/A'  # Get the location text or 'N/A' if not available

    # Append the extracted data to the list as a dictionary
    data.append({'Title': title, 'Price': price, 'Location': location})

# %%
# Convert the list of dictionaries to a DataFrame
df = pd.DataFrame(data)

# Display the first few rows of the DataFrame to verify the extracted data
print(df.head())
# Out:
#                                                Title   Price  \
# 0  DEAD CENTER CARROLL GARDENS! ABSOLUTE DREAM HO...  $5,042
# 1  Newly Renovated 3BR,, Heat & Hot Water Include...  $3,300
# 2  Stunning 6th floor 2bed2bath+balcony+elevator+...  $4,550
# 3  11/1 RENT STABILIZED FAB CHIC PRIME BUSHWICK 1...  $2,622
# 4  AMAZING 4 Bed 2 Bath + In-Unit W/D ✨20 min to ...  $3,600
#
#                                        Location
# 0                               Carroll Gardens
# 1                                       Astoria
# 2  Bed Stuy @ Nostrand A/C + Bedford/Nostrand G
# 3                                      Bushwick
# 4                                       Bedstuy

# %%
# Display the entire DataFrame to review all data
df
# Out:
#                                                  Title   Price  \
# 0    DEAD CENTER CARROLL GARDENS! ABSOLUTE DREAM HO...  $5,042
# 1    Newly Renovated 3BR,, Heat & Hot Water Include...  $3,300
# 2    Stunning 6th floor 2bed2bath+balcony+elevator+...  $4,550
# 3    11/1 RENT STABILIZED FAB CHIC PRIME BUSHWICK 1...  $2,622
# 4    AMAZING 4 Bed 2 Bath + In-Unit W/D ✨20 min to ...  $3,600
# ..                                                 ...     ...
# 346  Beautiful Large 2 Bedroom 1 Bath across the st...  $3,495
# 347  Gorgeous 5 Bedroom, 2 Full Bath with Laundry a...  $4,999
# 348                      JACKSON HEIGHTS- ELEV.-BLDG.-  $3,800
# 349  Spacious 2 Bedroom Apartment in Coveted Crown ...  $3,500
# 350                     🌟Huge Prospect Heights Studio!  $2,650
#
#                                          Location
# 0                                 Carroll Gardens
# 1                                         Astoria
# 2    Bed Stuy @ Nostrand A/C + Bedford/Nostrand G
# ...

# %%
df.to_csv('craigslist_nyc_apartments.csv', index=False)
